# %% [markdown]
# ## Setting up the environment and installing packages

# %%
# Cloning the BMLP repository and installing dependencies for Google Colab
# !git clone https://github.com/lun-ai/BMLP.git
# %cd /content/BMLP
# !git checkout dev
# !git submodule update --init --recursive
# !pip install -r requirements.txt

# %%
# Installing SWI-Prolog for Google Colab
# !sudo apt-add-repository -y ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog

# %%
# Installing Souffle
# !sudo apt-get --fix-broken install ./experiments/x86_64-ubuntu-2204-souffle-2.5-Linux.deb
# !mkdir experiments/bin
# !cp -r /usr/bin/souffle* experiments/bin

# %% [markdown]
# ## Running experiments on FB15k

# %%
# %cd /content/BMLP
import os
os.environ['PYTHONPATH'] = '/content/BMLP/'
# !bash run_exp.sh py-bmlp-gpu FB15K 10
# !bash run_exp.sh souffle FB15K 10
# !bash run_exp.sh bmlp-rms FB15K 10

# %% [markdown]
# ## Running experiments on DG

# %%
# %cd /content/BMLP
import os
os.environ['PYTHONPATH'] = '/content/BMLP/'
# !bash run_exp.sh py-bmlp-gpu full-5000-colab 10
# !bash run_exp.sh py-bmlp-rms full-5000-colab 10
# !bash run_exp.sh souffle full-5000-colab 10

# %% [markdown]
# ## Running experiments on DG+partial

# %%
# %cd /content/BMLP
import os
os.environ['PYTHONPATH'] = '/content/BMLP/'
# !bash run_exp.sh py-bmlp-gpu partial-5000 10
# !bash run_exp.sh bmlp-smp partial-5000 10
# !bash run_exp.sh souffle partial-5000 10
