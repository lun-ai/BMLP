# %%
from scripts.plots_and_stats import *

# %% [markdown]
# ## Compute mean and sterr data in Table 2

# %%
# DG
print("\n################ DG ################")
analysis_DG('experiments/path/full/runtime/local/',
            [0.01, 0.1, 0.5],
            5000,
            ['bmlp-rms', 'clg', 'bpl', 'swipl', 'souffle'])
# DG+partial
print("\n################ DG+partial ################")
analysis_DG('experiments/path/partial/runtime/local/',
            [0.01, 0.1, 0.5],
            5000,
            ['bmlp-smp', 'clg', 'bpl', 'swipl', 'souffle'])
# Out:
# ################ DG ################
# experiments/path/full/runtime/local/
# bpl
# $188.23 \pm 1.78$
# $1810.54 \pm 5.13$
# $10148.88 \pm 78.73$
# souffle
# $61.43 \pm 0.29$
# $324.91 \pm 0.62$
# $2810.35 \pm 7.79$
# swipl
# $843.0 \pm 11.61$
# $8838.07 \pm 41.71$
# $15000.0 \pm 0.0$
# clg
# $615.56 \pm 20.7$
# $5942.41 \pm 317.45$
# $15000.0 \pm 0.0$
# bmlp-rms
# $281.69 \pm 5.49$
# $248.78 \pm 4.47$
# $301.63 \pm 6.39$
#
# ################ DG+partial ################
# experiments/path/partial/runtime/local/
# bmlp-smp
# $0.61 \pm 0.08$
# $0.71 \pm 0.09$
# $0.85 \pm 0.18$
# bpl
# $112.66 \pm 1.71$
# $1130.61 \pm 9.77$
# $6025.05 \pm 57.92$
# souffle
# $58.09 \pm 1.31$
# $311.55 \pm 1.41$
# $2823.48 \pm 41.31$
# swipl
# $663.43 \pm 10.06$
# $7130.39 \pm 35.42$
# $15000.0 \pm 0.0$
# clg
# $584.79 \pm 6.5$
# $5976.29 \pm 15.23$
# $15000.0 \pm 0.0$

# %%
# FB15K-237
print("\n################ FB15K ################")
analysis_FB15K('experiments/FB15K/runtime/colab/')
# Out:
# ################ FB15K ################
# experiments/FB15K/runtime/colab/
# py-bmlp-gpu
# $2.09 \pm 0.04$
# souffle
# $44.69 \pm 1.38$

# %%
# DG
print("\n################ DG ################")
analysis_DG('experiments/path/full/runtime/colab/',
            [0.01, 0.1, 0.5],
            5000,
            ['py-bmlp-gpu', 'souffle'])
# DG+partial
print("\n################ DG+partial ################")
analysis_DG('experiments/path/partial/runtime/colab/',
            [0.01, 0.1, 0.5],
            5000,
            ['py-bmlp-gpu', 'souffle'])
# Out:
# ################ DG ################
# experiments/path/full/runtime/colab/
# py-bmlp-gpu
# $0.25 \pm 0.0$
# $0.25 \pm 0.0$
# $0.26 \pm 0.0$
# souffle
# $19.29 \pm 0.19$
# $82.91 \pm 0.47$
# $600.93 \pm 0.5$
#
# ################ DG+partial ################
# experiments/path/partial/runtime/colab/
# py-bmlp-gpu
# $0.24 \pm 0.0$
# $0.24 \pm 0.0$
# $0.25 \pm 0.0$
# souffle
# $16.06 \pm 0.17$
# $86.5 \pm 0.97$
# $620.45 \pm 2.2$

# %% [markdown]
# ## Plot Figure 4 and compute statistics in Figure 4

# %%
print("\n################ Figure 4 ################")
plot_DG('experiments/path/full/runtime/local/',
        [0.0001, 0.001, 0.01, 0.1, 0.5, 1],
        5000,
        ['bmlp-rms', 'clg', 'bpl', 'swipl', 'souffle'])
# plot Figure 5 and compute statistics in Figure 5
print("\n################ Figure 5 ################")
plot_DG_partial('experiments/path/partial/runtime/local/',
                0.001,
                5000,
                ['bmlp-smp', 'clg', 'bpl', 'swipl', 'souffle'])
# Out:
# ################ Figure 4 ################
# souffle
# $0.01 \pm 0.0$
# $11.67 \pm 0.31$
# $61.43 \pm 0.29$
# $324.91 \pm 0.62$
# $2810.35 \pm 7.79$
# $1518.34 \pm 4.06$
# bmlp-rms
# $2.58 \pm 0.33$
# $333.63 \pm 13.17$
# $281.69 \pm 5.49$
# $248.78 \pm 4.47$
# $301.63 \pm 6.39$
# $266.36 \pm 9.59$
# bpl
# $0.0 \pm 0.0$
# $42.41 \pm 0.33$
# $188.23 \pm 1.78$
# $1810.54 \pm 5.13$
# $10148.88 \pm 78.73$
# $15000.0 \pm 0.0$
# swipl
# $0.01 \pm 0.01$
# $104.59 \pm 0.88$
# $843.0 \pm 11.61$
# $8838.07 \pm 41.71$
# $15000.0 \pm 0.0$
# $15000.0 \pm 0.0$
# clg
# $0.07 \pm 0.02$
# $96.72 \pm 3.17$
# $615.56 \pm 20.7$
# $5942.41 \pm 317.45$
# $15000.0 \pm 0.0$
# $15000.0 \pm 0.0$
#
# ################ Figure 5 ################
# bpl
# $0.0 \pm 0.0$
# $0.94 \pm 0.11$
# $4.4 \pm 0.28$
# $14.1 \pm 0.4$
# $27.36 \pm 0.56$
# bmlp-smp
# $0.03 \pm 0.01$
# $0.08 \pm 0.02$
# $0.14 \pm 0.02$
# $0.25 \pm 0.04$
# $0.38 \pm 0.04$
# clg
# $0.02 \pm 0.02$
# $4.67 \pm 0.26$
# $17.71 \pm 0.55$
# ...
